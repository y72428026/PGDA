# %%
# walk the path, change the name
import os, shutil
path = '/data/yebh/mmdet2/configs/BIS'
for root, dir, files in os.walk(path):
    for file in files:
        if file.endswith('-7class.py'):
            # copy the file
            filedir = os.path.join(root, file)
            # shutil.chown(path)
            shutil.copy(filedir, filedir.replace('class', 'classbalance'))
            # input('ch')
